# %% [markdown]
# <a href="https://colab.research.google.com/github/Yiding5805/NYU_Summer-2021/blob/main/Econometrics_Milestone1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/eth.csv")
df.head()
# Out:
#          time  AdrActCnt  ...  VtyDayRet180d  VtyDayRet30d
# 0  2015-07-30     9206.0  ...            NaN           NaN
# 1  2015-07-31      424.0  ...            NaN           NaN
# 2  2015-08-01      413.0  ...            NaN           NaN
# 3  2015-08-02      432.0  ...            NaN           NaN
# 4  2015-08-03      444.0  ...            NaN           NaN
#
# [5 rows x 139 columns]

# %%
df=df.dropna()

# %% [markdown]
# #statistics

# %%
df.tail()
# Out:
#             time  AdrActCnt  ...  VtyDayRet180d  VtyDayRet30d
# 2121  2021-05-20   766729.0  ...       0.059584      0.081388
# 2122  2021-05-21   700299.0  ...       0.060591      0.085624
# 2123  2021-05-22   689227.0  ...       0.060504      0.085817
# 2124  2021-05-23   753755.0  ...       0.061000      0.087492
# 2125  2021-05-24   696056.0  ...       0.062832      0.096062
#
# [5 rows x 139 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of             time  AdrActCnt  ...  VtyDayRet180d  VtyDayRet30d
# 0     2015-07-30     9206.0  ...            NaN           NaN
# 1     2015-07-31      424.0  ...            NaN           NaN
# 2     2015-08-01      413.0  ...            NaN           NaN
# 3     2015-08-02      432.0  ...            NaN           NaN
# 4     2015-08-03      444.0  ...            NaN           NaN
# ...          ...        ...  ...            ...           ...
# 2121  2021-05-20   766729.0  ...       0.059584      0.081388
# 2122  2021-05-21   700299.0  ...       0.060591      0.085624
# 2123  2021-05-22   689227.0  ...       0.060504      0.085817
# 2124  2021-05-23   753755.0  ...       0.061000      0.087492
# 2125  2021-05-24   696056.0  ...       0.062832      0.096062
#
# [2126 rows x 139 columns]>

# %%
df.describe()
# Out:
#           AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet180d  VtyDayRet30d
# count  2.126000e+03       2126.000000  ...    1937.000000   2087.000000
# mean   2.742148e+05       6838.893697  ...       0.059016      0.056881
# std    3.176017e+05        827.467724  ...       0.014219      0.024712
# min    3.960000e+02       5323.000000  ...       0.035313      0.017667
# 25%    2.242600e+04       6296.000000  ...       0.048454      0.038060
# 50%    2.781330e+05       6872.000000  ...       0.058949      0.050054
# 75%    3.889275e+05       7342.250000  ...       0.065214      0.069720
# max    7.157228e+06       8814.000000  ...       0.096949      0.133661
#
# [8 rows x 138 columns]

# %% [markdown]
# #Regression

# %%
# define the dependent and the independent variable
X-df[[]]

# %%
# add a constant
